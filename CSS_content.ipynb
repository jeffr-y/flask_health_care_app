# %%
# Create a static folder and style CSS

import os

if not os.path.exists(r"C:\Users\jeffr\flask_health_care_app\static"):
    os.makedirs(r"C:\Users\jeffr\flask_health_care_app\static")

# Define CSS content
css_content = """
body {
    background-color: #f0f8ff;
    font-family: Arial, sans-serif;
}

h2 {
    color: #333;
}

input, select, button {
    padding: 5px;
    margin: 5px 0;
}

form {
    max-width: 400px;
    margin: auto;
}
"""

# save to static/style.css
with open(r"C:\Users\jeffr\flask_health_care_app\static\style.css", "w") as f:
        f.write(css_content)

print("style.css creared in static/ folder")
# Out:
# style.css creared in static/ folder
